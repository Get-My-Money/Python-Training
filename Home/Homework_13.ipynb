# %% [markdown]
# # Домашнее задание 13

# %% [markdown]
# ## Задача 1

# %% [markdown]
# Подготовится отвечать по Homework_12

# %% [markdown]
# ## Задача 2

# %% [markdown]
# В уроке 22 закончить функции authors_rating, save_to_file, add_quote, delete_quote
