# %% [markdown]
# Задание первое.

# %%
input_numbers = input().split()
numbers = []
for num in input_numbers:
    numbers.append(int(num))
result = []
for index in range(len(numbers)):
    if index % 2 == 1 and numbers[index] % 2 == 0:
        result.append(numbers[index])
print(result)
print(len(result))
# Out:
# 10 20 30 40 50 60
# [20, 40, 60]
# 3

# %% [markdown]
# Задание второе

# %%
input_numbers = input().split()
numbers = []
for num in input_numbers:
    numbers.append(int(num))
result = []
for i in range(len(numbers) - 1):
    diff = numbers[i + 1] - numbers[i]
    result.append(diff)
print(result)
# Out:
# 5 3 8 10
# [-2, 5, 2]

# %% [markdown]
# Задание третье

# %%
numbers = list(map(int, input().split()))
k = int(input())
k = k % len(numbers)
rotated = numbers[-k:] + numbers[:-k]
print(rotated)
# Out:
# 1 2 3 4 5
# 2
# [4, 5, 1, 2, 3]

# %% [markdown]
# Задание четвертое

# %%
film_name = input("Введите название фильма: ")
film_year = int(input("Введите год выпуска: "))
film_rating = int(input("Введите вашу оценку (от 1 до 10): "))
film_data = [
    ["Название", film_name],
    ["Год", film_year],
    ["Оценка", film_rating]
]
film_data.append(["Жанр", "Фантастика"])
slice_result = film_data[2:4]
print(slice_result)
# Out:
# Введите название фильма: Хроники
# Введите год выпуска: 1780
# Введите вашу оценку (от 1 до 10): 10
# [['Оценка', 10], ['Жанр', 'Фантастика']]
