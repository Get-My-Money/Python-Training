# %% [markdown]
# задание 1 - радар

# %%
numbers_input = input("Введите числа через пробел: ")
numbers_list = numbers_input.split()
numbers = []
for num in numbers_list:
    numbers.append(int(num))
x = int(input("Введите число : "))
found_indices = []
index = 0
for num in numbers:
    if num == x:
        found_indices.append(index)
    index += 1
if len(found_indices) == 0:
    print("Нет совпадений")
else:
    for i in found_indices:
        print(i, end=" ")
    print()
# Out:
# Введите числа через пробел:  2 10 25 40 512
# Введите число x: 10
# 1

# %% [markdown]
# Задание 2

# %%
numbers = []
total_sum = 0
sum_of_squares = 0
print("Вводите числа по одному. Для остановки введите числа, дающие в сумме 0.")
while True:
    num = int(input("Введите число: "))
    numbers.append(num)
    total_sum += num
    if total_sum == 0:
        break
for num in numbers:
    sum_of_squares += num ** 2
print("Сумма квадратов всех введенных чисел:", sum_of_squares)
# Out:
# Вводите числа по одному. Для остановки введите числа, дающие в сумме 0.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-9b816b225620> in <cell line: 0>()
#       4 print("Вводите числа по одному. Для остановки введите числа, дающие в сумме 0.")
#       5 while True:
# ----> 6     num = int(input("Введите число: "))
#       7     numbers.append(num)
#       8     total_sum += num
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# Задание 3

# %%
n = int(input("Введите количество элементов (n): "))
sequence = []
current_number = 1
while len(sequence) < n:
    for _ in range(current_number):
        sequence.append(current_number)
        if len(sequence) == n:
            break
    current_number += 1
print(' '.join(map(str, sequence[:n])))
# Out:
# Введите количество элементов (n): 10
# 1 2 2 3 3 3 4 4 4 4
